# %% [markdown]
# 1. question)   Define the role of a Data Analyst in your own words. What value do they bring to an organization?
#
#  -  data analyst process and examine the raw data, clean them and manupilate to look in a systemacitc, readable way. for the organisation the data is very important so data analyst convert raw data in a manner so company can make a dedcision with the help of data in a visulise way to understand properly.

# %% [markdown]
#  2. question  List three tools commonly used by Data Analysts and explain what each is mainly used for.)
#
#
#
# answer
#
# - power bi for visulation to look data in a readable way and clean in the from of chart or bar
#
# - mysql for record data in a table form and extract data from database and we can run query for data if we want exact or any specific data
#
# - python for clean or manipulate data , automation etc

# %% [markdown]
# 3. question  Write the end-to-end analytics workflow in the correct order and briefly explain each step.
#
#
# - define promblem
# - collect data
# - data preparation
# - visualize
# - analysis
# - decision

# %% [markdown]
# 4. question What is Prompt Engineering, and explain any two types of prompts used in Generative AI?
#
# answer4
#  -  prompt engineer create a prompt,  design , refine  them
# - zero shot prompt proivde no example in the input and relies on existing data .
# - few shot prompt provide several example of the input .

# %% [markdown]
#  5. question What are the key differences between a Business Analyst and a Data Analyst in terms of roles,
# responsibilities, and focus?
#
#  Answer
#    - FOCUS data analyst examines the raw data and converts into systematic and extracting the meaningful data and visualise so organisation can make decision with the help of data.
#
# - RESPONSIBILITY: COLLECT, CLEANING AND PROCESS DATA AND VISUALISE REPORT AND ASSURE ACCURACY AND QUALITY
#
# -  ROLE: INTERPRET DATA AND PRESENT .DATA
#
# - BUSINESS ANALYST: FOCUS: UNDERSTAND BUSINESS PROMBLEM AND FIND THE SOLUTION FOR A BUSINESS NEED ONLY
#
# - RESPONSIBILTY: PROVIDE DOCUMNENTING OR REQUIRE DATA FOR STACKEHOLDERS AND PROVIDE SOLUTION AND STRAGETIES AS WELL
#
# - ROLE: PROVIDE INSIGHT OF DATA OF A BUSINESS WHICH HELP THE STAKEHOLDER FOR A BETTER DECISION.

# %% [markdown]
# 6. question Explain any three AI-powered ETL (Extract, Transform, Load) tools and how they are used in analytics
#
# answer6
#  - informative intelligent data management cloud
# uses. (clean and prepare data from multiple sources)
# - qlik talend cloud : it help build analytic ready dataset by cleaning , transforming and intergrating data into form
# - windsor.ai : great for fast pipeline

# %% [markdown]
#  7. questionGive three applications of Data Analytics across different industries and explain how it creates value
#
#
# answer7
#   - health care industry  (predictive patient outcome) with the help of data analyst we can analys hospital patient data like how many have same disease or eating medicine and eating habit etc   .... which can help the hospital to care patient more carefully and cost effienct due to predeiction
#
# - marketing campaign  with the help of data, data analyst can use the data to see and analys the trend that see how many people like this product  or how many people for willing exaple ai reccomadation
#
# - finance (bank fraud alert) with the help of bank transcation bank can easily catch this abnormal transcation which can help in money laundering etc.

# %% [markdown]
# 8. question Explain the evolution of analytics, highlighting the different stages from Descriptive to Generative AI?
#
# answer8
#
# - descriptive analystic told what sold last month it show the history about the data or summary
# - diagnosis . why reuren increased it show what is the reason behind it
# - predictive. forecast demand  it show the forescast what will happen or tell future event
# - prescriptive. tell the solution about the promblem that what is beneficial for decision making
# - generative what can we produce with help of ai data analyst can enhance productivity
