# %% [markdown]
# 1 question)   Define the role of a Data Analyst in your own words. What value do they bring to an organization?
#
# answer1.  data analyst process and examine the raw data, clean them and manupilate to look in a systemacitc, readable way. for the organisation the data is very important so data analyst convert raw data in a manner so company can make a dedcision with the help of data in a visulise way to understand properly.

# %% [markdown]
#  question 2( List three tools commonly used by Data Analysts and explain what each is mainly used for.)
#
#
#
# answer2
#
# 1. power bi for visulation to look data in a readable way and clean in the from of chart or bar
#
# 2. mysql for record data in a table form and extract data from database and we can run query for data if we want exact or any specific data
#
# 3. python for clean or manipulate data , automation etc

# %% [markdown]
# question3  Write the end-to-end analytics workflow in the correct order and briefly explain each step.
#
# answer3
# 1. define promblem
# 2. collect data
# 3. data preparation
# 4. visualize
# 5. analysis
# 6. decision

# %% [markdown]
# question4 What is Prompt Engineering, and explain any two types of prompts used in Generative AI?
#
# answer4  prompt engineer create a prompt,  design , refine  them
# 1. zero shot prompt proivde no example in the input and relies on existing data .
# 2. few shot prompt provide several example of the input .

# %% [markdown]
#  question5. What are the key differences between a Business Analyst and a Data Analyst in terms of roles,
# responsibilities, and focus?
#
#
#  Answer5  1. FOCUS data analyst examines the raw data and converts into systematic and extracting the meaningful data and visualise so organisation can make decision with the help of data.
#
# 1.2  RESPONSIBILITY: COLLECT, CLEANING AND PROCESS DATA AND VISUALISE REPORT AND ASSURE ACCURACY AND QUALITY
#
# 1.3  ROLE: INTERPRET DATA AND PRESENT .DATA
#
# 2. BUSINESS ANALYST: FOCUS: UNDERSTAND BUSINESS PROMBLEM AND FIND THE SOLUTION FOR A BUSINESS NEED ONLY
#
# 2.1 RESPONSIBILTY: PROVIDE DOCUMNENTING OR REQUIRE DATA FOR STACKEHOLDERS AND PROVIDE SOLUTION AND STRAGETIES AS WELL
#
# 2.3 ROLE: PROVIDE INSIGHT OF DATA OF A BUSINESS WHICH HELP THE STAKEHOLDER FOR A BETTER DECISION.

# %% [markdown]
# question6  Explain any three AI-powered ETL (Extract, Transform, Load) tools and how they are used in analytics
#
# answer6 1. informative intelligent data management cloud
# uses. (clean and prepare data from multiple sources)

# %% [markdown]
# question7 Give three applications of Data Analytics across different industries and explain how it creates value
#
# answer7 1. health care industry  (predictive patient outcome) with the help of data analyst we can analys hospital patient data like how many have same disease or eating medicine and eating habit etc   .... which can help the hospital so care patient more carefully and cost effienct due to predeiction
#
# 2. marketing campaign  with the help of data, data analyst can use the data to see and analys the trend that see how many people like this product  or how many people for willing exaple ai reccomadation
#
# 3. finance (bank fraud alert) with the help of bank transcation bank can easily catch this abnormal transcation which can help in money laundering etc.

# %% [markdown]
# queastion8 Explain the evolution of analytics, highlighting the different stages from Descriptive to Generative AI?
#
# answer8
# 1. descriptive analystic told what sold last month it show the history about the data or summary
# 2. diagnosis . why reuren increased it show what is the reason behind it
# 3. predictive. forecast demand  it show the forescast what will happen or tell future event
# 4. prescriptive. tell the solution about the promblem that what is beneficial for decision making
# 5. generative what can we produce with help of ai data analyst can enhance productivity
